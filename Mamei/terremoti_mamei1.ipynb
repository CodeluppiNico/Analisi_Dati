# %%
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose
import math
import geopandas as gpd
import folium
import numpy as np
import datetime
from os import listdir
from os.path import isfile, join
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 6]
font = {'size'   : 20}
matplotlib.rc('font', **font)
from matplotlib import gridspec
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from datetime import datetime
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error

# %%
list_ddf_createri = pd.read_csv('terremoto/list_ddf_createri.csv')

# %%
list_ddf_createri
# Out:
#                    Comune  Cratere Centro Italia 2016  20150401_0000  \
# 0           Cerreto d'Esi                         1.0       11347.50
# 1                Fabriano                         1.0      127329.00
# 2        Acquasanta Terme                         1.0       13079.25
# 3    Appignano del Tronto                         1.0        9618.75
# 4      Arquata del Tronto                         1.0        4416.25
# ..                    ...                         ...            ...
# 658           Sante Marie                         0.0          52.25
# 659           Roccacasale                         0.0          11.00
# 660       Montorio Romano                         0.0          65.00
# 661              Manziana                         0.0           8.00
# 662                Celano                         0.0           5.00
#
#      20150401_0100  20150401_0200  20150401_0300  20150401_0400  \
# 0         11340.50       11365.75        11408.0       11417.25
# 1        126991.75      126224.50       125018.0      123984.25
# 2         13167.25       13192.75        13193.0       13184.25
# 3          9663.50        9776.00         9777.5        9784.00
# 4          4372.25        4371.00         4332.0        4240.50
# ..             ...            ...            ...            ...
# 658          52.25          53.00           54.5          54.75
# 659          11.00          11.00           11.0          11.00
# 660          65.00          65.75           66.5          67.00
# 661           8.25           9.00            9.0           9.00
# 662           5.00           5.00            5.0           5.00
#
#      20150401_0500  20150401_0600  20150401_0700  ...  20171030_1400  \
# 0         11295.50       11083.25       11051.75  ...       11580.25
# 1        122878.50      121562.75      123230.25  ...      159211.25
# 2         13064.25       12754.75       12808.75  ...       12408.50
# 3          9667.50        9429.50        9020.25  ...        8451.75
# 4          4152.75        4161.00        4213.00  ...        4476.00
# ..             ...            ...            ...  ...            ...
# 658          55.25          54.25          52.00  ...          32.00
# 659          11.00          11.00          11.00  ...          10.00
# 660          67.00          65.25          61.75  ...          38.25
# 661           9.00           9.00           8.00  ...           8.00
# 662           5.00           5.00           5.00  ...           5.00
#
#      20171030_1500  20171030_1600  20171030_1700  20171030_1800  \
# 0         11727.25       11779.75       11504.75       11113.00
# 1        161687.75      164929.50      166829.25      167358.00
# 2         12567.25       12658.00       12498.50       12468.50
# 3          8432.00        8465.25        8599.75        9072.75
# 4          4459.25        4381.50        3746.75        2678.25
# ..             ...            ...            ...            ...
# 658          31.75          31.25          30.75          30.75
# 659          10.00          10.00          10.00          10.00
# 660          39.00          39.25          41.50          49.25
# 661           8.25           8.75           9.00           9.00
# 662           5.00           5.00           5.00           4.75
#
#      20171030_1900  20171030_2000  20171030_2100  20171030_2200  20171030_2300
# 0         10960.75       11101.50       11181.00       11090.25       11036.75
# 1        163644.00      158348.00      153241.25      151060.00      147807.25
# 2         12605.50       12708.50       12656.00       12730.50       12839.75
# 3          9356.00        9667.75        9822.00        9874.50        9747.00
# 4          2400.75        2439.00        2008.50        1988.50        1963.50
# ..             ...            ...            ...            ...            ...
# 658          28.75          26.50          25.00          22.25          21.00
# 659          10.00          10.00          10.00          10.00          10.00
# 660          50.00          50.00          50.00          50.00          50.00
# 661           9.00           9.00           9.25           9.25           9.00
# 662           5.00           5.00           4.75           5.00           4.75
#
# [663 rows x 14422 columns]

# %%
terr1 = datetime.strptime('2016-08-24 03:00:00','%Y-%m-%d %H:%M:%S')
terr2 = datetime.strptime('2016-10-26 21:00:00','%Y-%m-%d %H:%M:%S')
wide = list_ddf_createri
df = list_ddf_createri.melt(id_vars=wide.columns[0:2],value_vars = wide.columns[2:])
df['datetime'] = pd.to_datetime(df['variable'], format = '%Y%m%d_%H%M')
#df['month'] = df['datetime'].dt.month
#df = df[df['month']!=10].drop('month',axis=1)

df  = df.drop('variable', axis=1)
s = df[df['Comune']=='Accumoli']
plt.plot(s['datetime'], s['value'])
plt.vlines([terr1,terr2],min(s['value']),max(s['value']),colors ='#ff0000')
plt.show()

# %%
df2 = df[df['value']>0]
tot = df2.groupby(['datetime'])['value'].sum().reset_index()
agg = df2.groupby(['Cratere Centro Italia 2016','datetime'])['value'].sum().reset_index()
c0 = agg[agg['Cratere Centro Italia 2016']==0]
c1 = agg[agg['Cratere Centro Italia 2016']==1]
agg.head()
# Out:
#    Cratere Centro Italia 2016            datetime        value
# 0                         0.0 2015-04-01 00:00:00  12266760.00
# 1                         0.0 2015-04-01 01:00:00  12257533.75
# 2                         0.0 2015-04-01 02:00:00  12240799.00
# 3                         0.0 2015-04-01 03:00:00  12212444.50
# 4                         0.0 2015-04-01 04:00:00  12141105.00

# %%
terr1 = datetime.strptime('2016-06-24 03:00:00','%Y-%m-%d %H:%M:%S')
terr2 = datetime.strptime('2016-10-26 21:00:00','%Y-%m-%d %H:%M:%S')
t1 = datetime.strptime('2016-06-24 03:00:00','%Y-%m-%d %H:%M:%S')
t2 = datetime.strptime('2017-12-24 03:00:00','%Y-%m-%d %H:%M:%S')
#plt.subplot(1, 3, 1)
#s = tot
#plt.plot(s['datetime'], s['value'])
#plt.vlines([terr1,terr2],min(s['value']),max(s['value']))
plt.subplot(2, 1, 1)
s = c0
plt.plot(s['datetime'], s['value'])
plt.vlines([terr1,terr2],min(s['value']),max(s['value']))
#plt.xlim(t1,t2)
plt.subplot(2, 1, 2)
s = c1
plt.plot(s['datetime'], s['value'])
plt.vlines([terr1,terr2],min(s['value']),max(s['value']))
#plt.xlim(t1,t2)
plt.show()

# %%
tot = df2.groupby(['datetime'])['value'].sum().reset_index()
agg = df2.groupby(['Cratere Centro Italia 2016','datetime'])['value'].sum().reset_index()
c0 = agg[agg['Cratere Centro Italia 2016']==0].drop('Cratere Centro Italia 2016',axis=1)
c1 = agg[agg['Cratere Centro Italia 2016']==1].drop('Cratere Centro Italia 2016',axis=1)

singolo = df2[df2['Comune']=='Amatrice'].drop(['Comune','Cratere Centro Italia 2016'],axis=1)
singolo = singolo[singolo['value']>0]

serie = c1.copy()
print(serie.shape)
serie
# Out:
# (14196, 2)
#                  datetime       value
# 14196 2015-04-01 00:00:00  2201743.75
# 14197 2015-04-01 01:00:00  2200744.75
# 14198 2015-04-01 02:00:00  2198148.50
# 14199 2015-04-01 03:00:00  2194298.00
# 14200 2015-04-01 04:00:00  2182447.25
# ...                   ...         ...
# 28387 2017-10-30 19:00:00  2377928.75
# 28388 2017-10-30 20:00:00  2348838.75
# 28389 2017-10-30 21:00:00  2325105.50
# 28390 2017-10-30 22:00:00  2310442.50
# 28391 2017-10-30 23:00:00  2298855.50
#
# [14196 rows x 2 columns]

# %%
def add_feature(serie):
    
    serie['year'] = serie['datetime'].dt.year - 2015
    
    #month = pd.get_dummies(serie['datetime'].dt.month, prefix='month') #one hot encoding
    #serie = pd.concat([serie,month],axis='columns')
    
    week = pd.get_dummies(serie['datetime'].dt.isocalendar().week, prefix='week') #one hot encoding
    serie = pd.concat([serie,week],axis='columns')

    day_of_week = pd.get_dummies(serie['datetime'].dt.dayofweek, prefix='day') #one hot encoding
    serie = pd.concat([serie,day_of_week],axis='columns')

    hours = pd.get_dummies(serie['datetime'].dt.hour, prefix='h') #one hot encoding
    serie = pd.concat([serie,hours],axis='columns')
    
    return serie

# %%
def fill_missing_data(serie):

    serie_init = serie.copy()

    serie = serie.append({'datetime':datetime.strptime('2015-10-14 00:00:00','%Y-%m-%d %H:%M:%S'),'value':np.nan}, ignore_index = True)
    serie = serie.append({'datetime':datetime.strptime('2015-10-21 00:00:00','%Y-%m-%d %H:%M:%S'),'value':np.nan}, ignore_index = True)
    serie = serie.append({'datetime':datetime.strptime('2015-10-28 00:00:00','%Y-%m-%d %H:%M:%S'),'value':np.nan}, ignore_index = True)
    serie = serie.sort_values(by=['datetime'])
    serie = add_feature(serie)

    model = LinearRegression()
    f = serie.columns[2:]
    model.fit(serie.dropna(axis='rows').loc[:,f], serie.dropna(axis='rows')['value'])


    yp = model.predict(serie.loc[:,f])
    serie['yp'] = yp


    addition = serie.loc[serie['value'].isna(),['yp','datetime']]
    addition.columns = ['value','datetime']
    addition

    serie_init = pd.concat([serie_init,addition])
    serie_init = serie_init.sort_values(by=['datetime'])
    serie = serie_init

    return serie

# %%
serie = fill_missing_data(serie)
serie = add_feature(serie)

terr1 = datetime.strptime('2016-08-24 03:00:00','%Y-%m-%d %H:%M:%S')


train = serie[serie['datetime'] < terr1]
test = serie[serie['datetime'] >= terr1]
#print(sorted(np.unique(train['datetime'].dt.isocalendar().week)))
#print(sorted(np.unique(test['datetime'].dt.isocalendar().week)))
print(train.shape)
print(test.shape)
# Out:
# (7554, 66)
# (6645, 66)

# %%
model = LinearRegression()
f = serie.columns[2:]
print(list(f))
model.fit(train.loc[:,f], train['value'])
print('coef = ',model.coef_)
print('intercept = ', model.intercept_)
# Out:
# ['year', 'week_13', 'week_14', 'week_15', 'week_16', 'week_17', 'week_18', 'week_19', 'week_20', 'week_21', 'week_22', 'week_23', 'week_24', 'week_25', 'week_26', 'week_27', 'week_28', 'week_29', 'week_30', 'week_31', 'week_32', 'week_33', 'week_34', 'week_35', 'week_36', 'week_37', 'week_38', 'week_39', 'week_40', 'week_41', 'week_42', 'week_43', 'week_44', 'day_0', 'day_1', 'day_2', 'day_3', 'day_4', 'day_5', 'day_6', 'h_0', 'h_1', 'h_2', 'h_3', 'h_4', 'h_5', 'h_6', 'h_7', 'h_8', 'h_9', 'h_10', 'h_11', 'h_12', 'h_13', 'h_14', 'h_15', 'h_16', 'h_17', 'h_18', 'h_19', 'h_20', 'h_21', 'h_22', 'h_23']
# coef =  [ 1.99081954e+05  7.43796795e+15  7.43796795e+15  7.43796795e+15
#   7.43796795e+15  7.43796795e+15  7.43796795e+15  7.43796795e+15
#   7.43796795e+15  7.43796795e+15  7.43796795e+15  7.43796795e+15
#   7.43796795e+15  7.43796795e+15  7.43796795e+15  7.43796795e+15
#   7.43796795e+15  7.43796795e+15  7.43796795e+15  7.43796795e+15
#   7.43796795e+15  7.43796795e+15  7.43796795e+15  7.43796795e+15
#   7.43796795e+15  7.43796795e+15  7.43796795e+15  7.43796795e+15
#   7.43796795e+15  7.43796795e+15  7.43796795e+15  7.43796795e+15
#   7.43796795e+15 -1.06699306e+17 -1.06699306e+17 -1.06699306e+17
#  -1.06699306e+17 -1.06699306e+17 -1.06699306e+17 -1.06699306e+17
#   1.69743946e+16  1.69743946e+16  1.69743946e+16  1.69743946e+16
#   1.69743946e+16  1.69743946e+16  1.69743946e+16  1.69743946e+16
#   1.69743946e+16  1.69743946e+16  1.69743946e+16  1.69743946e+16
#   1.69743946e+16  1.69743946e+16  1.69743946e+16  1.69743946e+16
#   1.69743946e+16  1.69743946e+16  1.69743946e+16  1.69743946e+16
#   1.69743946e+16  1.69743946e+16  1.69743946e+16  1.69743946e+16]
# intercept =  8.228694384087678e+16

# %%
yp = model.predict(test.loc[:,f])
plt.figure(figsize = (20, 4))
plt.plot(serie['datetime'],serie['value'],label='original')
plt.plot(test['datetime'],yp,label='forecast')
plt.legend(loc="lower right")
t1 = datetime.strptime('2015-09-24 03:00:00','%Y-%m-%d %H:%M:%S')
t2 = datetime.strptime('2015-12-29 03:00:00','%Y-%m-%d %H:%M:%S')
#plt.xlim(t1,t2)
plt.show()

from sklearn.metrics import mean_absolute_percentage_error
print('MAPE =',mean_absolute_percentage_error(test.loc[:,'value'],yp)*100,'%') 
print('Calo = ',np.mean(((test.loc[:,'value'] - yp) / yp)) * 100,'%') #non absolute
# Out:
# MAPE = 7.555778791581662 %
# Calo =  -6.487911601433778 %

# %% [markdown]
# # Regressione su Ogni singolo Comune

# %%
# faccop quello che ho fatto sopra con un for su tutti i comuni


nome_comune =  []
cratere = []
variaz = []

comuni = list(np.unique(df2['Comune']))
for i in range(len(comuni)):
    print(comuni[i],i,'/',len(comuni))
    singolo = df2[df2['Comune']==comuni[i]]
    crat = int(singolo['Cratere Centro Italia 2016'].iloc[0])
    singolo = singolo[singolo['value']>0].drop(['Comune','Cratere Centro Italia 2016'],axis=1)
    serie = singolo.copy()
    serie = fill_missing_data(serie)
    serie = add_feature(serie)

    terr1 = datetime.strptime('2016-08-24 03:00:00','%Y-%m-%d %H:%M:%S')

    train = serie[serie['datetime'] < terr1]
    test = serie[serie['datetime'] >= terr1]

    model = LinearRegression()
    f = serie.columns[2:]
    model.fit(train.loc[:,f], train['value'])
    yp = model.predict(test.loc[:,f])
    #print('MAPE =',mean_absolute_percentage_error(test.loc[:,'value'],yp)*100,'%') 
    c = np.mean(((test.loc[:,'value'] - yp) / yp)) * 100
    #print('Calo = ',c,'%') #non absolute
    nome_comune.append(comuni[i])
    cratere.append(crat)
    variaz.append(c)
variaz_df = pd.DataFrame({'Comune':nome_comune,'Cratere Centro Italia 2016':cratere,'Variaz':variaz})
variaz_df
# Out:
# Abbateggio 0 / 663
# Acciano 1 / 663
# Accumoli 2 / 663
# Acquacanina 3 / 663
# Acqualagna 4 / 663
# Acquapendente 5 / 663
# Acquasanta Terme 6 / 663
# Acquasparta 7 / 663
# Acquaviva Picena 8 / 663
# Agugliano 9 / 663
# Alanno 10 / 663
# Alba Adriatica 11 / 663
# Allerona 12 / 663
# Allumiere 13 / 663
# Altidona 14 / 663
# Alviano 15 / 663
# Amandola 16 / 663
# Amatrice 17 / 663
# Amelia 18 / 663
# Ancarano 19 / 663
# Ancona 20 / 663
# Anghiari 21 / 663
# Antrodoco 22 / 663
# Apecchio 23 / 663
# Apiro 24 / 663
# Appignano 25 / 663
# Appignano del Tronto 26 / 663
# Arcevia 27 / 663
# Arezzo 28 / 663
# Ari 29 / 663
# Arielli 30 / 663
# Arlena di Castro 31 / 663
# Arquata del Tronto 32 / 663
# Arrone 33 / 663
# Arsita 34 / 663
# Ascoli Piceno 35 / 663
# Ascrea 36 / 663
# Assisi 37 / 663
# Atri 38 / 663
# Attigliano 39 / 663
# Avigliano Umbro 40 / 663
# Badia Tedalda 41 / 663
# Bagnoregio 42 / 663
# Barbara 43 / 663
# Barbarano Romano 44 / 663
# Barchi 45 / 663
# Barete 46 / 663
# Barisciano 47 / 663
# Baschi 48 / 663
# Basciano 49 / 663
# Bassano Romano 50 / 663
# Bassano in Teverina 51 / 663
# Bastia Umbra 52 / 663
# Belforte all'Isauro 53 / 663
# Belforte del Chienti 54 / 663
# Bellante 55 / 663
# Belmonte Piceno 56 / 663
# Belmonte in Sabina 57 / 663
# Belvedere Ostrense 58 / 663
# Bettona 59 / 663
# Bevagna 60 / 663
# Bibbiena 61 / 663
# Bisenti 62 / 663
# Blera 63 / 663
# Bolognano 64 / 663
# Bolognola 65 / 663
# Bolsena 66 / 663
# Bomarzo 67 / 663
# Borbona 68 / 663
# Borgo Pace 69 / 663
# Borgo Velino 70 / 663
# Borgorose 71 / 663
# Bracciano 72 / 663
# Brittoli 73 / 663
# Bucchianico 74 / 663
# Bussi sul Tirino 75 / 663
# Cagli 76 / 663
# Cagnano Amiterno 77 / 663
# Calascio 78 / 663
# Calcata 79 / 663
# Caldarola 80 / 663
# Calvi dell'Umbria 81 / 663
# Camerano 82 / 663
# Camerata Picena 83 / 663
# Camerino 84 / 663
# Campagnano di Roma 85 / 663
# Campello sul Clitunno 86 / 663
# Campli 87 / 663
# Campofilone 88 / 663
# Camporotondo di Fiastrone 89 / 663
# Campotosto 90 / 663
# Canale Monterano 91 / 663
# Canepina 92 / 663
# Cannara 93 / 663
# Canosa Sannita 94 / 663
# Cantalice 95 / 663
# Cantalupo in Sabina 96 / 663
# Cantiano 97 / 663
# Canzano 98 / 663
# Capena 99 / 663
# Capestrano 100 / 663
# Capitignano 101 / 663
# Capodimonte 102 / 663
# Capolona 103 / 663
# Caporciano 104 / 663
# Cappelle sul Tavo 105 / 663
# Capranica 106 / 663
# Caprarola 107 / 663
# Caprese Michelangelo 108 / 663
# Caramanico Terme 109 / 663
# Carapelle Calvisio 110 / 663
# Carassai 111 / 663
# Carbognano 112 / 663
# Carpegna 113 / 663
# Carpineto della Nora 114 / 663
# Carsoli 115 / 663
# Cartoceto 116 / 663
# Casacanditella 117 / 663
# Casalincontrada 118 / 663
# Casaprota 119 / 663
# Cascia 120 / 663
# Casoli 121 / 663
# Casperia 122 / 663
# Castel Castagna 123 / 663
# Castel Focognano 124 / 663
# Castel Frentano 125 / 663
# Castel Giorgio 126 / 663
# Castel Ritaldi 127 / 663
# Castel Sant'Angelo 128 / 663
# Castel Sant'Elia 129 / 663
# Castel Viscardo 130 / 663
# Castel del Monte 131 / 663
# Castel di Lama 132 / 663
# Castel di Tora 133 / 663
# Castelbellino 134 / 663
# Casteldelci 135 / 663
# Castelfidardo 136 / 663
# Castellalto 137 / 663
# Castelleone di Suasa 138 / 663
# Castelli 139 / 663
# Castelnuovo di Farfa 140 / 663
# Castelplanio 141 / 663
# Castelraimondo 142 / 663
# Castelsantangelo sul Nera 143 / 663
# Castelvecchio Calvisio 144 / 663
# Castiglion Fiorentino 145 / 663
# Castiglione Messer Raimondo 146 / 663
# Castiglione a Casauria 147 / 663
# Castiglione del Lago 148 / 663
# Castiglione in Teverina 149 / 663
# Castignano 150 / 663
# Castilenti 151 / 663
# Castorano 152 / 663
# Catignano 153 / 663
# Celano 154 / 663
# Celleno 155 / 663
# Cellino Attanasio 156 / 663
# Cepagatti 157 / 663
# Cermignano 158 / 663
# Cerreto d'Esi 159 / 663
# Cerreto di Spoleto 160 / 663
# Cessapalombo 161 / 663
# Cetona 162 / 663
# Chianciano Terme 163 / 663
# Chiaravalle 164 / 663
# Chieti 165 / 663
# Chitignano 166 / 663
# Chiusi 167 / 663
# Chiusi della Verna 168 / 663
# Cingoli 169 / 663
# Citerna 170 / 663
# Cittaducale 171 / 663
# Cittareale 172 / 663
# Città Sant'Angelo 173 / 663
# Città della Pieve 174 / 663
# Città di Castello 175 / 663
# Civita Castellana 176 / 663
# Civitanova Marche 177 / 663
# Civitaquana 178 / 663
# Civitella Casanova 179 / 663
# Civitella San Paolo 180 / 663
# Civitella d'Agliano 181 / 663
# Civitella del Tronto 182 / 663
# Collalto Sabino 183 / 663
# Collazzone 184 / 663
# Colle di Tora 185 / 663
# Collecorvino 186 / 663
# Colledara 187 / 663
# Collegiove 188 / 663
# Collepietro 189 / 663
# Collevecchio 190 / 663
# Colli del Tronto 191 / 663
# Colli sul Velino 192 / 663
# Colmurano 193 / 663
# Colonnella 194 / 663
# Comunanza 195 / 663
# Concerviano 196 / 663
# Configni 197 / 663
# Contigliano 198 / 663
# Controguerra 199 / 663
# Corchiano 200 / 663
# Corciano 201 / 663
# Corfinio 202 / 663
# Corinaldo 203 / 663
# Corridonia 204 / 663
# Corropoli 205 / 663
# Cortino 206 / 663
# Cortona 207 / 663
# Corvara 208 / 663
# Cossignano 209 / 663
# Costacciaro 210 / 663
# Cottanello 211 / 663
# Crecchio 212 / 663
# Crognaleto 213 / 663
# Cugnoli 214 / 663
# Cupra Marittima 215 / 663
# Cupramontana 216 / 663
# Deruta 217 / 663
# Elice 218 / 663
# Esanatoglia 219 / 663
# Fabriano 220 / 663
# Fabrica di Roma 221 / 663
# Fabro 222 / 663
# Fagnano Alto 223 / 663
# Falconara Marittima 224 / 663
# Faleria 225 / 663
# Falerone 226 / 663
# Fano 227 / 663
# Fano Adriano 228 / 663
# Fara Filiorum Petri 229 / 663
# Fara in Sabina 230 / 663
# Farindola 231 / 663
# Ferentillo 232 / 663
# Fermignano 233 / 663
# Fermo 234 / 663
# Fiamignano 235 / 663
# Fiano Romano 236 / 663
# Fiastra 237 / 663
# Ficulle 238 / 663
# Filacciano 239 / 663
# Filetto 240 / 663
# Filottrano 241 / 663
# Fiordimonte 242 / 663
# Fiuminata 243 / 663
# Foiano della Chiana 244 / 663
# Folignano 245 / 663
# Foligno 246 / 663
# Fontecchio 247 / 663
# Forano 248 / 663
# Force 249 / 663
# Fossa 250 / 663
# Fossato di Vico 251 / 663
# Fossombrone 252 / 663
# Francavilla al Mare 253 / 663
# Francavilla d'Ete 254 / 663
# Frasso Sabino 255 / 663
# Fratta Todina 256 / 663
# Fratte Rosa 257 / 663
# Frisa 258 / 663
# Frontino 259 / 663
# Frontone 260 / 663
# Gagliole 261 / 663
# Gallese 262 / 663
# Genga 263 / 663
# Giano dell'Umbria 264 / 663
# Giove 265 / 663
# Giuliano Teatino 266 / 663
# Giulianova 267 / 663
# Gradoli 268 / 663
# Graffignano 269 / 663
# Greccio 270 / 663
# Grottammare 271 / 663
# Grottazzolina 272 / 663
# Grotte di Castro 273 / 663
# Gualdo 274 / 663
# Gualdo Cattaneo 275 / 663
# Gualdo Tadino 276 / 663
# Guardea 277 / 663
# Guardiagrele 278 / 663
# Gubbio 279 / 663
# Isola del Gran Sasso d'Italia 280 / 663
# Isola del Piano 281 / 663
# Jesi 282 / 663
# L'Aquila 283 / 663
# Labro 284 / 663
# Lanciano 285 / 663
# Lapedona 286 / 663
# Latera 287 / 663
# Leonessa 288 / 663
# Lettomanoppello 289 / 663
# Lisciano Niccone 290 / 663
# Longone Sabino 291 / 663
# Loreto 292 / 663
# Loreto Aprutino 293 / 663
# Loro Piceno 294 / 663
# Lubriano 295 / 663
# Lucoli 296 / 663
# Lugnano in Teverina 297 / 663
# Lunano 298 / 663
# Macerata 299 / 663
# Magione 300 / 663
# Magliano Romano 301 / 663
# Magliano Sabina 302 / 663
# Magliano de' Marsi 303 / 663
# Magliano di Tenna 304 / 663
# Maiolati Spontini 305 / 663
# Maltignano 306 / 663
# Manoppello 307 / 663
# Manziana 308 / 663
# Marcetelli 309 / 663
# Marciano della Chiana 310 / 663
# Mare 311 / 663
# Marsciano 312 / 663
# Marta 313 / 663
# Martinsicuro 314 / 663
# Massa Fermana 315 / 663
# Massa Martana 316 / 663
# Massa d'Albe 317 / 663
# Massignano 318 / 663
# Matelica 319 / 663
# Mazzano Romano 320 / 663
# Mercatello sul Metauro 321 / 663
# Mergo 322 / 663
# Micigliano 323 / 663
# Miglianico 324 / 663
# Mogliano 325 / 663
# Molina Aterno 326 / 663
# Mompeo 327 / 663
# Mondavio 328 / 663
# Mondolfo 329 / 663
# Monsampietro Morico 330 / 663
# Monsampolo del Tronto 331 / 663
# Monsano 332 / 663
# Montalto delle Marche 333 / 663
# Montappone 334 / 663
# Montasola 335 / 663
# Monte Castello di Vibio 336 / 663
# Monte Cavallo 337 / 663
# Monte Giberto 338 / 663
# Monte Porzio 339 / 663
# Monte Rinaldo 340 / 663
# Monte Roberto 341 / 663
# Monte Romano 342 / 663
# Monte San Giovanni in Sabina 343 / 663
# Monte San Giusto 344 / 663
# Monte San Martino 345 / 663
# Monte San Pietrangeli 346 / 663
# Monte San Vito 347 / 663
# Monte Santa Maria Tiberina 348 / 663
# Monte Urano 349 / 663
# Monte Vidon Combatte 350 / 663
# Monte Vidon Corrado 351 / 663
# Montebello di Bertona 352 / 663
# Montebuono 353 / 663
# Montecarotto 354 / 663
# Montecassiano 355 / 663
# Montecastrilli 356 / 663
# Montecchio 357 / 663
# Montecosaro 358 / 663
# Montedinove 359 / 663
# Montefalco 360 / 663
# Montefalcone Appennino 361 / 663
# Montefano 362 / 663
# Montefelcino 363 / 663
# Montefiascone 364 / 663
# Montefino 365 / 663
# Montefiore dell'Aso 366 / 663
# Montefortino 367 / 663
# Montefranco 368 / 663
# Montegabbione 369 / 663
# Montegallo 370 / 663
# Montegiorgio 371 / 663
# Montegranaro 372 / 663
# Monteleone Sabino 373 / 663
# Monteleone d'Orvieto 374 / 663
# Monteleone di Fermo 375 / 663
# Monteleone di Spoleto 376 / 663
# Montelibretti 377 / 663
# Montelparo 378 / 663
# Montelupone 379 / 663
# Montemaggiore al Metauro 380 / 663
# Montemarciano 381 / 663
# Montemonaco 382 / 663
# Montenero Sabino 383 / 663
# Monteprandone 384 / 663
# Montepulciano 385 / 663
# Monterchi 386 / 663
# Montereale 387 / 663
# Monterosi 388 / 663
# Monterubbiano 389 / 663
# Montesilvano 390 / 663
# Montone 391 / 663
# Montopoli di Sabina 392 / 663
# Montorio Romano 393 / 663
# Montorio al Vomano 394 / 663
# Montottone 395 / 663
# Moresco 396 / 663
# Morlupo 397 / 663
# Morro Reatino 398 / 663
# Morro d'Alba 399 / 663
# Morro d'Oro 400 / 663
# Morrovalle 401 / 663
# Mosciano Sant'Angelo 402 / 663
# Moscufo 403 / 663
# Muccia 404 / 663
# Narni 405 / 663
# Navelli 406 / 663
# Nazzano 407 / 663
# Nepi 408 / 663
# Nereto 409 / 663
# Nerola 410 / 663
# Nespolo 411 / 663
# Nocciano 412 / 663
# Nocera Umbra 413 / 663
# None 414 / 663
# Norcia 415 / 663
# Notaresco 416 / 663
# Numana 417 / 663
# Ocre 418 / 663
# Ofena 419 / 663
# Offagna 420 / 663
# Offida 421 / 663
# Onano 422 / 663
# Orciano di Pesaro 423 / 663
# Oriolo Romano 424 / 663
# Orsogna 425 / 663
# Orte 426 / 663
# Ortezzano 427 / 663
# Ortona 428 / 663
# Orvieto 429 / 663
# Orvinio 430 / 663
# Osimo 431 / 663
# Ostra 432 / 663
# Ostra Vetere 433 / 663
# Otricoli 434 / 663
# Ovindoli 435 / 663
# Paciano 436 / 663
# Paganico Sabino 437 / 663
# Palmiano 438 / 663
# Panicale 439 / 663
# Parrano 440 / 663
# Passignano sul Trasimeno 441 / 663
# Pedaso 442 / 663
# Peglio 443 / 663
# Penna San Giovanni 444 / 663
# Penna Sant'Andrea 445 / 663
# Penna in Teverina 446 / 663
# Pennabilli 447 / 663
# Pennapiedimonte 448 / 663
# Penne 449 / 663
# Pergola 450 / 663
# Perugia 451 / 663
# Pescara 452 / 663
# Pescorocchiano 453 / 663
# Pescosansonesco 454 / 663
# Petrella Salto 455 / 663
# Petriano 456 / 663
# Petriolo 457 / 663
# Petritoli 458 / 663
# Piagge 459 / 663
# Piandimeleto 460 / 663
# Pianella 461 / 663
# Piansano 462 / 663
# Picciano 463 / 663
# Piegaro 464 / 663
# Pietracamela 465 / 663
# Pietralunga 466 / 663
# Pietranico 467 / 663
# Pieve Santo Stefano 468 / 663
# Pieve Torina 469 / 663
# Pievebovigliana 470 / 663
# Pineto 471 / 663
# Piobbico 472 / 663
# Pioraco 473 / 663
# Pizzoli 474 / 663
# Poggio Bustone 475 / 663
# Poggio Catino 476 / 663
# Poggio Mirteto 477 / 663
# Poggio Moiano 478 / 663
# Poggio Nativo 479 / 663
# Poggio Picenze 480 / 663
# Poggio San Lorenzo 481 / 663
# Poggio San Marcello 482 / 663
# Poggio San Vicino 483 / 663
# Poggiodomo 484 / 663
# Poggiofiorito 485 / 663
# Polino 486 / 663
# Pollenza 487 / 663
# Polverigi 488 / 663
# Ponzano Romano 489 / 663
# Ponzano di Fermo 490 / 663
# Popoli 491 / 663
# Porano 492 / 663
# Porto Recanati 493 / 663
# Porto San Giorgio 494 / 663
# Porto Sant'Elpidio 495 / 663
# Posta 496 / 663
# Potenza Picena 497 / 663
# Pozzaglia Sabina 498 / 663
# Prata d'Ansidonia 499 / 663
# Preci 500 / 663
# Pretoro 501 / 663
# Proceno 502 / 663
# Radicofani 503 / 663
# Rapagnano 504 / 663
# Rapino 505 / 663
# Recanati 506 / 663
# Rieti 507 / 663
# Rignano Flaminio 508 / 663
# Ripa Teatina 509 / 663
# Ripatransone 510 / 663
# Ripe San Ginesio 511 / 663
# Rivodutri 512 / 663
# Rocca Santa Maria 513 / 663
# Rocca Sinibalda 514 / 663
# Rocca di Cambio 515 / 663
# Rocca di Mezzo 516 / 663
# Roccacasale 517 / 663
# Roccafluvione 518 / 663
# Roccamontepiano 519 / 663
# Roccamorice 520 / 663
# Roccantica 521 / 663
# Ronciglione 522 / 663
# Rosciano 523 / 663
# Roseto degli Abruzzi 524 / 663
# Rosora 525 / 663
# Rotella 526 / 663
# Salisano 527 / 663
# Salle 528 / 663
# Saltara 529 / 663
# San Benedetto del Tronto 530 / 663
# San Benedetto in Perillis 531 / 663
# San Casciano dei Bagni 532 / 663
# San Costanzo 533 / 663
# San Demetrio ne' Vestini 534 / 663
# San Gemini 535 / 663
# San Ginesio 536 / 663
# San Giorgio di Pesaro 537 / 663
# San Giovanni Teatino 538 / 663
# San Giustino 539 / 663
# San Lorenzo Nuovo 540 / 663
# San Lorenzo in Campo 541 / 663
# San Marcello 542 / 663
# San Martino sulla Marrucina 543 / 663
# San Paolo di Jesi 544 / 663
# San Pio delle Camere 545 / 663
# San Severino Marche 546 / 663
# San Valentino in Abruzzo Citeriore 547 / 663
# San Venanzo 548 / 663
# San Vito Chietino 549 / 663
# Sansepolcro 550 / 663
# Sant'Anatolia di Narco 551 / 663
# Sant'Angelo in Pontano 552 / 663
# Sant'Angelo in Vado 553 / 663
# Sant'Egidio alla Vibrata 554 / 663
# Sant'Elpidio a Mare 555 / 663
# Sant'Eusanio Forconese 556 / 663
# Sant'Eusanio del Sangro 557 / 663
# Sant'Ippolito 558 / 663
# Sant'Omero 559 / 663
# Sant'Oreste 560 / 663
# Santa Maria Nuova 561 / 663
# Santa Vittoria in Matenano 562 / 663
# Sante Marie 563 / 663
# Santo Stefano di Sessanio 564 / 663
# Sarnano 565 / 663
# Sarteano 566 / 663
# Sassocorvaro 567 / 663
# Sassoferrato 568 / 663
# Scafa 569 / 663
# Scandriglia 570 / 663
# Scheggia e Pascelupo 571 / 663
# Scheggino 572 / 663
# Scoppito 573 / 663
# Secinaro 574 / 663
# Sefro 575 / 663
# Selci 576 / 663
# Sellano 577 / 663
# Senigallia 578 / 663
# Serra San Quirico 579 / 663
# Serra Sant'Abbondio 580 / 663
# Serra de' Conti 581 / 663
# Serramonacesca 582 / 663
# Serrapetrona 583 / 663
# Serravalle di Chienti 584 / 663
# Serrungarina 585 / 663
# Servigliano 586 / 663
# Sestino 587 / 663
# Sigillo 588 / 663
# Silvi 589 / 663
# Sinalunga 590 / 663
# Sirolo 591 / 663
# Smerillo 592 / 663
# Soriano nel Cimino 593 / 663
# Spello 594 / 663
# Spinetoli 595 / 663
# Spoleto 596 / 663
# Spoltore 597 / 663
# Staffolo 598 / 663
# Stimigliano 599 / 663
# Stroncone 600 / 663
# Subbiano 601 / 663
# Sutri 602 / 663
# Tarano 603 / 663
# Tarquinia 604 / 663
# Teramo 605 / 663
# Terni 606 / 663
# Tione degli Abruzzi 607 / 663
# Tocco da Casauria 608 / 663
# Todi 609 / 663
# Toffia 610 / 663
# Tolentino 611 / 663
# Tolfa 612 / 663
# Tollo 613 / 663
# Torano Nuovo 614 / 663
# Torgiano 615 / 663
# Tornimparte 616 / 663
# Torre San Patrizio 617 / 663
# Torre de' Passeri 618 / 663
# Torrevecchia Teatina 619 / 663
# Torri in Sabina 620 / 663
# Torricella Sicura 621 / 663
# Torricella in Sabina 622 / 663
# Torrita Tiberina 623 / 663
# Torrita di Siena 624 / 663
# Tortoreto 625 / 663
# Tossicia 626 / 663
# Trecastelli 627 / 663
# Treia 628 / 663
# Trevi 629 / 663
# Trevignano Romano 630 / 663
# Tuoro sul Trasimeno 631 / 663
# Turrivalignani 632 / 663
# Tuscania 633 / 663
# Umbertide 634 / 663
# Urbania 635 / 663
# Urbino 636 / 663
# Urbisaglia 637 / 663
# Ussita 638 / 663
# Vacone 639 / 663
# Vacri 640 / 663
# Valentano 641 / 663
# Valfabbrica 642 / 663
# Valle Castellana 643 / 663
# Vallerano 644 / 663
# Vallo di Nera 645 / 663
# Valtopina 646 / 663
# Varco Sabino 647 / 663
# Vasanello 648 / 663
# Vejano 649 / 663
# Venarotta 650 / 663
# Verghereto 651 / 663
# Vetralla 652 / 663
# Vicoli 653 / 663
# Vignanello 654 / 663
# Villa Celiera 655 / 663
# Villa San Giovanni in Tuscia 656 / 663
# Villa Sant'Angelo 657 / 663
# Villa Santa Lucia degli Abruzzi 658 / 663
# Villamagna 659 / 663
# Visso 660 / 663
# Viterbo 661 / 663
# Vitorchiano 662 / 663
#                               Comune  Cratere Centro Italia 2016     Variaz
# 0                         Abbateggio                           0 -14.463097
# 1                            Acciano                           0 -14.871586
# 2                           Accumoli                           1 -50.164385
# 3                        Acquacanina                           1 -34.796726
# 4                         Acqualagna                           0  -9.514810
# ..                               ...                         ...        ...
# 658  Villa Santa Lucia degli Abruzzi                           0 -10.222365
# 659                       Villamagna                           0  -4.337131
# 660                            Visso                           1 -39.940610
# 661                          Viterbo                           0   7.166067
# 662                      Vitorchiano                           0  15.859289
#
# [663 rows x 3 columns]

# %%
variaz_df.to_csv('terremoto/variaz_phone.csv',index=False)

# %%
alldata_reshape = pd.read_csv('terremoto/alldata_reshape.csv')
alldata_reshape = alldata_reshape.loc[:,['Comune','pop_fine_2016']]
alldata_reshape['size'] = alldata_reshape['pop_fine_2016'] / 100
alldata_reshape
# Out:
#                               Comune  pop_fine_2016   size
# 0                            Acciano          319.0   3.19
# 1                           Accumoli          639.0   6.39
# 2                   Acquasanta Terme         2868.0  28.68
# 3                        Acquasparta         4667.0  46.67
# 4                   Acquaviva Picena         3793.0  37.93
# ..                               ...            ...    ...
# 380                     Varco Sabino          184.0   1.84
# 381                        Venarotta         2072.0  20.72
# 382                Villa Sant'Angelo          429.0   4.29
# 383  Villa Santa Lucia degli Abruzzi          111.0   1.11
# 384                            Visso         1106.0  11.06
#
# [385 rows x 3 columns]

# %%
variaz = pd.read_csv('terremoto/variaz_phone.csv', sep=',')
variaz_df2 = pd.merge(variaz, alldata_reshape, how='inner', on='Comune')
v0 = variaz_df2[variaz_df2['Cratere Centro Italia 2016']==0]
v1 = variaz_df2[variaz_df2['Cratere Centro Italia 2016']==1]
plt.scatter(v0['Cratere Centro Italia 2016'],v0['Variaz'],s=v0['size'],alpha=0.7)
plt.scatter(v1['Cratere Centro Italia 2016'],v1['Variaz'],s=v1['size'],alpha=0.7)
plt.axhline(y = 0, color = '#000000', linestyle = 'dashed')
plt.show()

# %% [markdown]
# # Confrontiamo con i dati dell'ISTAT

# %%
from datetime import datetime
t = datetime.strptime('2016-08-24 03:00:00','%Y-%m-%d %H:%M:%S')
df['hour'] = df['datetime'].dt.hour
df2 = df[df['hour'].isin([22,23,0,1,2,3,4,5])]

# %%
pre = df2[df2['datetime'] < t]
post = df2[df2['datetime'] > t]
m_pre = pre.groupby(['Comune','Cratere Centro Italia 2016'])['value'].mean().reset_index()
m_pre = m_pre.rename(columns={'value':'media_prima'})
m_post = post.groupby(['Comune','Cratere Centro Italia 2016'])['value'].mean().reset_index()
m_post = m_post.rename(columns={'value':'media_dopo'})
m = pd.concat([m_pre,m_post],axis='columns')
m = m.iloc[:,[0,1,2,5]]
m['varPhones'] = (m['media_dopo'] - m['media_prima']) / m['media_prima']
medie_prima_dopo = m
medie_prima_dopo
# Out:
#                               Comune  Cratere Centro Italia 2016  \
# 0                         Abbateggio                         0.0
# 1                            Acciano                         0.0
# 2                           Accumoli                         1.0
# 3                        Acquacanina                         1.0
# 4                         Acqualagna                         0.0
# ..                               ...                         ...
# 658  Villa Santa Lucia degli Abruzzi                         0.0
# 659                       Villamagna                         0.0
# 660                            Visso                         1.0
# 661                          Viterbo                         0.0
# 662                      Vitorchiano                         0.0
#
#        media_prima     media_dopo  varPhones
# 0      1633.760638    1760.015597   0.077279
# 1      2560.456228    2732.586008   0.067226
# 2      6171.785673    2520.818603  -0.591558
# 3      2203.589215    1719.542948  -0.219663
# 4     20774.803092   22628.154837   0.089212
# ..             ...            ...        ...
# 658    2065.680550    2051.115167  -0.007051
# 659    7665.233803    8903.941117   0.161601
# 660   12484.397673    7964.049051  -0.362080
# 661  199688.296311  233533.890710   0.169492
# 662   10981.136232   14538.708409   0.323971
#
# [663 rows x 5 columns]

# %%
alldata_reshape = pd.read_csv('terremoto/alldata_reshape.csv')
alldata_reshape['var2016'] = (alldata_reshape['pop_fine_2016'] - alldata_reshape['pop_iniz_2016']) / (alldata_reshape['pop_iniz_2016']) 
alldata_reshape['var2017'] = (alldata_reshape['pop_fine_2017'] - alldata_reshape['pop_iniz_2017']) / (alldata_reshape['pop_iniz_2017'])  
alldata_reshape['var2017all'] = (alldata_reshape['pop_fine_2017'] - alldata_reshape['pop_iniz_2016']) / (alldata_reshape['pop_iniz_2016'])  
alldata_reshape['delta2016'] = (alldata_reshape['iscr2016'] - alldata_reshape['canc2016']) / (alldata_reshape['pop_fine_2016']) 
alldata_reshape['delta2017'] = (alldata_reshape['iscr2017'] - alldata_reshape['canc2017']) / (alldata_reshape['pop_fine_2017']) 
alldata_reshape.replace([np.inf, -np.inf], np.nan, inplace=True)
k = ['Comune']+list(alldata_reshape.columns[-6:])
alldata_reshape
# Out:
#                               Comune  canc2015  canc2016  canc2017  iscr2015  \
# 0                            Acciano      11.0      21.0      10.0       9.0
# 1                           Accumoli      30.0      17.0      13.0      28.0
# 2                   Acquasanta Terme     101.0      88.0      67.0      76.0
# 3                        Acquasparta     173.0     142.0     126.0     136.0
# 4                   Acquaviva Picena     143.0     146.0     133.0      97.0
# ..                               ...       ...       ...       ...       ...
# 380                     Varco Sabino      14.0      14.0      19.0      11.0
# 381                        Venarotta      47.0      66.0      53.0      45.0
# 382                Villa Sant'Angelo      18.0      20.0       9.0      27.0
# 383  Villa Santa Lucia degli Abruzzi       3.0       6.0       4.0       7.0
# 384                            Visso      39.0      30.0      33.0      14.0
#
#      iscr2016  iscr2017  pop_iniz_2015  pop_iniz_2016  pop_iniz_2017  \
# 0        19.0      12.0          347.0          335.0          319.0
# 1        19.0       6.0          665.0          655.0          639.0
# 2        52.0      23.0         2994.0         2935.0         2868.0
# 3       130.0     147.0         4786.0         4705.0         4667.0
# 4       115.0     141.0         3878.0         3829.0         3793.0
# ..        ...       ...            ...            ...            ...
# 380      17.0       9.0          193.0          185.0          184.0
# 381      69.0      40.0         2111.0         2079.0         2072.0
# 382      11.0      19.0          436.0          440.0          429.0
# 383       0.0       4.0          127.0          125.0          111.0
# 384      39.0       9.0         1148.0         1108.0         1106.0
#
#      pop_fine_2015  pop_fine_2016  pop_fine_2017  Cratere Centro Italia 2016  \
# 0            335.0          319.0          317.0                         0.0
# 1            655.0          639.0          616.0                         1.0
# 2           2935.0         2868.0         2801.0                         1.0
# 3           4705.0         4667.0         4636.0                         0.0
# 4           3829.0         3793.0         3778.0                         0.0
# ..             ...            ...            ...                         ...
# 380          185.0          184.0          169.0                         0.0
# 381         2079.0         2072.0         2054.0                         1.0
# 382          440.0          429.0          436.0                         0.0
# 383          125.0          111.0          108.0                         0.0
# 384         1108.0         1106.0         1074.0                         1.0
#
#       var2016   var2017  var2017all  delta2016  delta2017
# 0   -0.047761 -0.006270   -0.053731  -0.006270   0.006309
# 1   -0.024427 -0.035994   -0.059542   0.003130  -0.011364
# 2   -0.022828 -0.023361   -0.045656  -0.012552  -0.015709
# 3   -0.008077 -0.006642   -0.014665  -0.002571   0.004530
# 4   -0.009402 -0.003955   -0.013319  -0.008173   0.002118
# ..        ...       ...         ...        ...        ...
# 380 -0.005405 -0.081522   -0.086486   0.016304  -0.059172
# 381 -0.003367 -0.008687   -0.012025   0.001448  -0.006329
# 382 -0.025000  0.016317   -0.009091  -0.020979   0.022936
# 383 -0.112000 -0.027027   -0.136000  -0.054054   0.000000
# 384 -0.001805 -0.028933   -0.030686   0.008137  -0.022346
#
# [385 rows x 19 columns]

# %%
dati_corr = pd.merge(alldata_reshape, medie_prima_dopo.drop('Cratere Centro Italia 2016',axis=1), how='inner', on='Comune')
dati_corr['size'] = dati_corr['pop_fine_2016'] / 100
dati_corr
# Out:
#                               Comune  canc2015  canc2016  canc2017  iscr2015  \
# 0                            Acciano      11.0      21.0      10.0       9.0
# 1                           Accumoli      30.0      17.0      13.0      28.0
# 2                   Acquasanta Terme     101.0      88.0      67.0      76.0
# 3                        Acquasparta     173.0     142.0     126.0     136.0
# 4                   Acquaviva Picena     143.0     146.0     133.0      97.0
# ..                               ...       ...       ...       ...       ...
# 380                     Varco Sabino      14.0      14.0      19.0      11.0
# 381                        Venarotta      47.0      66.0      53.0      45.0
# 382                Villa Sant'Angelo      18.0      20.0       9.0      27.0
# 383  Villa Santa Lucia degli Abruzzi       3.0       6.0       4.0       7.0
# 384                            Visso      39.0      30.0      33.0      14.0
#
#      iscr2016  iscr2017  pop_iniz_2015  pop_iniz_2016  pop_iniz_2017  ...  \
# 0        19.0      12.0          347.0          335.0          319.0  ...
# 1        19.0       6.0          665.0          655.0          639.0  ...
# 2        52.0      23.0         2994.0         2935.0         2868.0  ...
# 3       130.0     147.0         4786.0         4705.0         4667.0  ...
# 4       115.0     141.0         3878.0         3829.0         3793.0  ...
# ..        ...       ...            ...            ...            ...  ...
# 380      17.0       9.0          193.0          185.0          184.0  ...
# 381      69.0      40.0         2111.0         2079.0         2072.0  ...
# 382      11.0      19.0          436.0          440.0          429.0  ...
# 383       0.0       4.0          127.0          125.0          111.0  ...
# 384      39.0       9.0         1148.0         1108.0         1106.0  ...
#
#      Cratere Centro Italia 2016   var2016   var2017  var2017all  delta2016  \
# 0                           0.0 -0.047761 -0.006270   -0.053731  -0.006270
# 1                           1.0 -0.024427 -0.035994   -0.059542   0.003130
# 2                           1.0 -0.022828 -0.023361   -0.045656  -0.012552
# 3                           0.0 -0.008077 -0.006642   -0.014665  -0.002571
# 4                           0.0 -0.009402 -0.003955   -0.013319  -0.008173
# ..                          ...       ...       ...         ...        ...
# 380                         0.0 -0.005405 -0.081522   -0.086486   0.016304
# 381                         1.0 -0.003367 -0.008687   -0.012025   0.001448
# 382                         0.0 -0.025000  0.016317   -0.009091  -0.020979
# 383                         0.0 -0.112000 -0.027027   -0.136000  -0.054054
# 384                         1.0 -0.001805 -0.028933   -0.030686   0.008137
#
#      delta2017   media_prima    media_dopo  varPhones   size
# 0     0.006309   2560.456228   2732.586008   0.067226   3.19
# 1    -0.011364   6171.785673   2520.818603  -0.591558   6.39
# 2    -0.015709  15586.085229  15172.258024  -0.026551  28.68
# 3     0.004530  19690.498972  22873.044982   0.161629  46.67
# 4     0.002118  15769.157282  18471.370705   0.171361  37.93
# ..         ...           ...           ...        ...    ...
# 380  -0.059172    870.905226    695.584087  -0.201309   1.84
# 381  -0.006329   9838.056273   9966.172129   0.013022  20.72
# 382   0.022936    773.198515    891.929589   0.153558   4.29
# 383   0.000000   2065.680550   2051.115167  -0.007051   1.11
# 384  -0.022346  12484.397673   7964.049051  -0.362080  11.06
#
# [385 rows x 23 columns]

# %%
crat0 = dati_corr[dati_corr['Cratere Centro Italia 2016']==0]
crat1 = dati_corr[dati_corr['Cratere Centro Italia 2016']==1]
plt.scatter(crat0['pop_fine_2016'],crat0['media_dopo'],alpha=0.7)
plt.scatter(crat1['pop_fine_2016'],crat1['media_dopo'],alpha=0.7)
plt.xlabel('pop_fine_2016')
plt.ylabel('media_dopo')
plt.show()

# %%
variaz = pd.read_csv('terremoto/variaz_phone.csv', sep=',')
medie_prima_dopo = medie_prima_dopo.merge(variaz)
medie_prima_dopo.to_csv('terremoto/variaz_phone_all.csv',index=False)
medie_prima_dopo.head(2)
# Out:
#        Comune  Cratere Centro Italia 2016  media_prima   media_dopo  \
# 0  Abbateggio                         0.0  1633.760638  1760.015597
# 1     Acciano                         0.0  2560.456228  2732.586008
#
#    varPhones     Variaz
# 0   0.077279 -14.463097
# 1   0.067226 -14.871586

# %%
crat0 = medie_prima_dopo[medie_prima_dopo['Cratere Centro Italia 2016']==0]
crat1 = medie_prima_dopo[medie_prima_dopo['Cratere Centro Italia 2016']==1]
plt.scatter(crat0['varPhones'],crat0['Variaz'],alpha=0.7)
plt.scatter(crat1['varPhones'],crat1['Variaz'],alpha=0.7)
plt.xlabel('varPhones')
plt.ylabel('Variaz')
plt.show()

# %%
fig = plt.figure(figsize=(16,10))
v = 'var2016'
for c in ['Amatrice','Camerino','Accumoli']:
    eg = dati_corr[dati_corr['Comune']==c].reset_index()
    plt.scatter(eg[v],eg['varPhones'],c='#000000',s=10)
    plt.text(eg[v],eg['varPhones'],eg['Comune'][0])


crat0 = dati_corr[dati_corr['Cratere Centro Italia 2016']==0]
crat1 = dati_corr[dati_corr['Cratere Centro Italia 2016']==1]
    
plt.scatter(crat0[v],crat0['varPhones'],alpha=0.7,s=crat0['size'],label='No Cratere')
plt.scatter(crat1[v],crat1['varPhones'],alpha=0.7,s=crat1['size'],label='Cratere')

plt.xlabel(v)
plt.ylabel('varPhones')
plt.legend(loc='best')
plt.show()

# %%
fig = plt.figure(figsize=(16,10))
font = {'size'   : 10}
matplotlib.rc('font', **font)
correlation_mat = abs(dati_corr.corr())
ax = sns.heatmap(correlation_mat, annot = True,fmt = '.2f')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %% [markdown]
# # Riprovo la correlazione con il risultato della predizione

# %%
v = 'var2016'
my_crateri = alldata_reshape[['Comune','Cratere Centro Italia 2016',v]]
my_crateri = my_crateri.dropna(axis='rows')
my_crateri = pd.merge(variaz_df2[['Comune','Variaz','size']], my_crateri, how='inner', on='Comune')
my_crateri
crat0 = my_crateri[my_crateri['Cratere Centro Italia 2016']==0]
crat1 = my_crateri[my_crateri['Cratere Centro Italia 2016']==1]
plt.scatter(crat0['Cratere Centro Italia 2016'],crat0[v],alpha=0.7,s=crat0['size'])
plt.scatter(crat1['Cratere Centro Italia 2016'],crat1[v],alpha=0.7,s=crat1['size'])
plt.axhline(y = 0, color = '#000000', linestyle = 'dashed')
plt.show()

# %%
fig = plt.figure(figsize=(16,10))
for c in ['Amatrice','Camerino','Accumoli']:
    eg = my_crateri[my_crateri['Comune']==c].reset_index()
    plt.scatter(eg[v],eg['Variaz'],c='#000000',s=10)
    plt.text(eg[v],eg['Variaz'],eg['Comune'][0])

crat0 = my_crateri[my_crateri['Cratere Centro Italia 2016']==0]
crat1 = my_crateri[my_crateri['Cratere Centro Italia 2016']==1]
plt.scatter(crat0[v],crat0['Variaz'],alpha=0.7,s=crat0['size'],label='No Cratere')
plt.scatter(crat1[v],crat1['Variaz'],alpha=0.7,s=crat1['size'],label='Cratere')
plt.xlabel(v)
plt.ylabel('varPhones')
plt.legend(loc='best')
plt.show()

# %%
correlation_mat = (my_crateri.corr())
correlation_mat
# Out:
#                               Variaz      size  Cratere Centro Italia 2016  \
# Variaz                      1.000000  0.056152                   -0.226910
# size                        0.056152  1.000000                   -0.076555
# Cratere Centro Italia 2016 -0.226910 -0.076555                    1.000000
# var2016                     0.125552  0.141353                   -0.083788
#
#                              var2016
# Variaz                      0.125552
# size                        0.141353
# Cratere Centro Italia 2016 -0.083788
# var2016                     1.000000
